# %%
import pandas as pd

# %% [markdown]
# ## Learning datatypes

# %%
# 1-D datatype -- Series
series = pd.Series(["BMW","Toyota","Honda"])
print(series)
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
color = pd.Series(["White","Blue","Green"])
color
# Out:
# 0    White
# 1     Blue
# 2    Green
# dtype: object

# %%
# 2-D datatype -- DataFrame

car_data = pd.DataFrame({"Type" : series,"Color" : color})
car_data
# Out:
#      Type  Color
# 0     BMW  White
# 1  Toyota   Blue
# 2   Honda  Green

# %%
# import data

car_table = pd.read_csv("car-sales.csv")
car_table
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Describe Data

# %%
#Attribute - will not have (); its for getting the details 
car_table.dtypes

#function - has (); it performs some steps once called
# car_table.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_table.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
# describe works for only numerical columns
car_table.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_table["Doors"].sum()
# Out:
# 40

# %%
len(car_table)
# Out:
# 10

# %%
car_table.head(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_table.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# ## loc & iloc

# %%
car_table1 = pd.Series(["Testla", "BMW", "Honda", "Xcent", "Maruti"], index = [2,4,6,8,10])
car_table1
# Out:
# 2     Testla
# 4        BMW
# 6      Honda
# 8      Xcent
# 10    Maruti
# dtype: object

# %%
# .loc refers to index

car_table1.loc[:4]
# Out:
# 2    Testla
# 4       BMW
# dtype: object

# %%
# .iloc refers to position 

car_table1.iloc[:4]
# Out:
# 2    Testla
# 4       BMW
# 6     Honda
# 8     Xcent
# dtype: object

# %%
car_table.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_table["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_table[car_table["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_table[car_table["Doors"] <= 3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
pd.crosstab(car_table["Make"], car_table["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_table.groupby(["Make"]).max()
# Out:
#        Colour  Odometer (KM)  Doors       Price
# Make
# BMW     Black          11179      5  $22,000.00
# Honda     Red          87899      4   $7,500.00
# Nissan  White         213095      4   $9,700.00
# Toyota  White         150043      4   $7,000.00

# %%
car_table["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_table["Doors"].plot()
# Out:
# <AxesSubplot:>

# %%
car_table["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
# car_table["Price"] = car_table["Price"].str.replace('[\$\,\.]', '').astype(int)
car_table
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_table_3 = pd.read_csv("car-sales.csv")

# %%
car_table_3
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_table_3["Price"] = car_table_3["Price"].str.replace('[\$\,]', '').astype(float)

# %%
car_table_3
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_table_3["Price"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipulating Data

# %%
car_table["Make"] = car_table["Make"].str.lower()

# %%
car_table
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_table["Make"] = car_table["Make"].str.capitalize()

# %%
car_table
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     Bmw  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_table_mis = pd.read_csv("car-sales-extended-missing-data.csv")

# %%
car_table_mis
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_table_mis.loc[car_table_mis['Odometer (KM)'] == 35431.0]
# Out:
#     Make Colour  Odometer (KM)  Doors    Price
# 0  Honda  White        35431.0    4.0  15323.0

# %%
car_table_mis.loc[car_table_mis['Odometer (KM)'].isnull()]
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 7     Honda  White            NaN    4.0  20306.0
# 37   Nissan  White            NaN    4.0  15131.0
# 72    Honda  White            NaN    4.0   5648.0
# 86   Nissan   Blue            NaN    4.0   3300.0
# 129  Toyota  White            NaN    4.0  35358.0
# 141  Toyota  White            NaN    4.0  34133.0
# 144     BMW   Blue            NaN    5.0  30412.0
# 178   Honda  White            NaN    4.0  10076.0
# 209   Honda  White            NaN    4.0  22746.0
# 215     BMW  White            NaN    5.0  38128.0
# 235  Toyota  Green            NaN    4.0  19936.0
# 252   Honda    NaN            NaN    4.0   7076.0
# 254  Nissan   Blue            NaN    4.0  18182.0
# 276   Honda    NaN            NaN    4.0  28983.0
# 281     BMW   Blue            NaN    3.0  16391.0
# 313     BMW    NaN            NaN    5.0  32887.0
# 316  Toyota  White            NaN    4.0      NaN
# 319  Nissan  White            NaN    3.0  23868.0
# ...

# %%
car_table_mis['Odometer (KM)'] = car_table_mis['Odometer (KM)'].fillna(car_table_mis['Odometer (KM)'].mean(), inplace=True)

# %%
car_table_mis.head(40)
# Out:
#       Make Colour Odometer (KM)  Doors    Price
# 0    Honda  White          None    4.0  15323.0
# 1      BMW   Blue          None    5.0  19943.0
# 2    Honda  White          None    4.0  28343.0
# 3   Toyota  White          None    4.0  13434.0
# 4   Nissan   Blue          None    3.0  14043.0
# 5    Honda    Red          None    4.0  23883.0
# 6   Toyota   Blue          None    4.0   8473.0
# 7    Honda  White          None    4.0  20306.0
# 8      NaN  White          None    4.0   9374.0
# 9    Honda   Blue          None    4.0  26683.0
# 10  Nissan  White          None    4.0  16259.0
# 11  Nissan  Green          None    4.0   6160.0
# 12  Nissan  White          None    4.0  16909.0
# 13     NaN  White          None    4.0  11121.0
# 14   Honda   Blue          None    4.0  18946.0
# 15  Toyota   Blue          None    4.0  16290.0
# 16  Toyota    Red          None    4.0  34465.0
# 17     BMW  White          None    5.0  17177.0
# 18  Nissan  White          None    3.0   9109.0
# ...

# %%
car_table_mis.loc[car_table_mis["Odometer (KM)"] == 35431]
# Out:
# Empty DataFrame
# Columns: [Make, Colour, Odometer (KM), Doors, Price]
# Index: []

# %%
car_table_mis.head(40)
# Out:
#       Make Colour Odometer (KM)  Doors    Price
# 0    Honda  White          None    4.0  15323.0
# 1      BMW   Blue          None    5.0  19943.0
# 2    Honda  White          None    4.0  28343.0
# 3   Toyota  White          None    4.0  13434.0
# 4   Nissan   Blue          None    3.0  14043.0
# 5    Honda    Red          None    4.0  23883.0
# 6   Toyota   Blue          None    4.0   8473.0
# 7    Honda  White          None    4.0  20306.0
# 8      NaN  White          None    4.0   9374.0
# 9    Honda   Blue          None    4.0  26683.0
# 10  Nissan  White          None    4.0  16259.0
# 11  Nissan  Green          None    4.0   6160.0
# 12  Nissan  White          None    4.0  16909.0
# 13     NaN  White          None    4.0  11121.0
# 14   Honda   Blue          None    4.0  18946.0
# 15  Toyota   Blue          None    4.0  16290.0
# 16  Toyota    Red          None    4.0  34465.0
# 17     BMW  White          None    5.0  17177.0
# 18  Nissan  White          None    3.0   9109.0
# ...

# %%
car_table_mis.loc[car_table_mis['Price'].isnull()]
# Out:
#        Make Colour Odometer (KM)  Doors  Price
# 119     BMW  White          None    5.0    NaN
# 152  Toyota  White          None    4.0    NaN
# 171  Toyota  White          None    4.0    NaN
# 176  Toyota   Blue          None    4.0    NaN
# 249     BMW    Red          None    5.0    NaN
# 256     NaN   Blue          None    4.0    NaN
# 258  Nissan    Red          None    4.0    NaN
# 316  Toyota  White          None    4.0    NaN
# 335  Toyota  Black          None    4.0    NaN
# 337   Honda  Black          None    4.0    NaN
# 379   Honda  White          None    4.0    NaN
# 398  Toyota  White          None    4.0    NaN
# 413  Toyota    NaN          None    4.0    NaN
# 422  Toyota  White          None    4.0    NaN
# 423  Nissan  Black          None    4.0    NaN
# 474  Nissan    NaN          None    4.0    NaN
# 480  Toyota  Black          None    4.0    NaN
# 504  Toyota  Black          None    4.0    NaN
# 507  Toyota   Blue          None    4.0    NaN
# ...

# %%
car_table_mis['Price'] = car_table_mis['Price'].fillna(car_table_mis['Price'].mean())

# %%
car_table_mis.tail(50)
# Out:
#        Make Colour Odometer (KM)  Doors         Price
# 950   Honda  White          None    4.0  11548.000000
# 951   Honda  White          None    4.0  14849.000000
# 952  Nissan  White          None    4.0  16042.814737
# 953     BMW  White          None    5.0  29551.000000
# 954  Toyota   Blue          None    4.0  32509.000000
# 955  Toyota    NaN          None    4.0  10261.000000
# 956  Toyota  Black          None    4.0  33758.000000
# 957  Nissan    NaN          None    3.0  12315.000000
# 958   Honda   Blue          None    4.0  28422.000000
# 959  Nissan  White          None    4.0  16042.814737
# 960   Honda  White          None    4.0  13070.000000
# 961  Toyota  White          None    4.0   4896.000000
# 962   Honda   Blue          None    4.0  15010.000000
# 963  Toyota  White          None    4.0   7126.000000
# 964  Toyota   Blue          None    4.0  34231.000000
# 965   Honda   Blue          None    4.0  14691.000000
# ...

# %%
car_table_mis.loc[car_table_mis['Price']==16042]
# Out:
# Empty DataFrame
# Columns: [Make, Colour, Odometer (KM), Doors, Price]
# Index: []

# %%
car_table_mis['Price'].fillna(car_table_mis['Price'].mean(),inplace=True)

# %%
car_table_mis.tail(50)
# Out:
#        Make Colour Odometer (KM)  Doors         Price
# 950   Honda  White          None    4.0  11548.000000
# 951   Honda  White          None    4.0  14849.000000
# 952  Nissan  White          None    4.0  16042.814737
# 953     BMW  White          None    5.0  29551.000000
# 954  Toyota   Blue          None    4.0  32509.000000
# 955  Toyota    NaN          None    4.0  10261.000000
# 956  Toyota  Black          None    4.0  33758.000000
# 957  Nissan    NaN          None    3.0  12315.000000
# 958   Honda   Blue          None    4.0  28422.000000
# 959  Nissan  White          None    4.0  16042.814737
# 960   Honda  White          None    4.0  13070.000000
# 961  Toyota  White          None    4.0   4896.000000
# 962   Honda   Blue          None    4.0  15010.000000
# 963  Toyota  White          None    4.0   7126.000000
# 964  Toyota   Blue          None    4.0  34231.000000
# 965   Honda   Blue          None    4.0  14691.000000
# ...

# %%
car_table_mis.loc[car_table_mis['Price']==16042]
# Out:
# Empty DataFrame
# Columns: [Make, Colour, Odometer (KM), Doors, Price]
# Index: []

# %%
pddd = pd.DataFrame()

# %%
pddd = car_table_mis

# %%
pddd['Doors'].replace(4.0, 4.5, inplace=True)

# %%
pddd
# Out:
#        Make Colour Odometer (KM)  Doors    Price
# 0     Honda  White          None    4.5  15323.0
# 1       BMW   Blue          None    5.0  19943.0
# 2     Honda  White          None    4.5  28343.0
# 3    Toyota  White          None    4.5  13434.0
# 4    Nissan   Blue          None    3.0  14043.0
# ..      ...    ...           ...    ...      ...
# 995  Toyota  Black          None    4.5  32042.0
# 996     NaN  White          None    3.0   5716.0
# 997  Nissan   Blue          None    4.5  31570.0
# 998   Honda  White          None    4.5   4001.0
# 999  Toyota   Blue          None    4.5  12732.0
#
# [1000 rows x 5 columns]

# %%
pddd.loc[pddd['Doors']==4.5]
# Out:
#        Make Colour Odometer (KM)  Doors    Price
# 0     Honda  White          None    4.5  15323.0
# 2     Honda  White          None    4.5  28343.0
# 3    Toyota  White          None    4.5  13434.0
# 5     Honda    Red          None    4.5  23883.0
# 6    Toyota   Blue          None    4.5   8473.0
# ..      ...    ...           ...    ...      ...
# 993  Nissan  Black          None    4.5   4696.0
# 995  Toyota  Black          None    4.5  32042.0
# 997  Nissan   Blue          None    4.5  31570.0
# 998   Honda  White          None    4.5   4001.0
# 999  Toyota   Blue          None    4.5  12732.0
#
# [811 rows x 5 columns]

# %%
car_table_mis.dropna()
# Out:
# Empty DataFrame
# Columns: [Make, Colour, Odometer (KM), Doors, Price]
# Index: []

# %%
car_table_mis
# Out:
#        Make Colour Odometer (KM)  Doors    Price
# 0     Honda  White          None    4.5  15323.0
# 1       BMW   Blue          None    5.0  19943.0
# 2     Honda  White          None    4.5  28343.0
# 3    Toyota  White          None    4.5  13434.0
# 4    Nissan   Blue          None    3.0  14043.0
# ..      ...    ...           ...    ...      ...
# 995  Toyota  Black          None    4.5  32042.0
# 996     NaN  White          None    3.0   5716.0
# 997  Nissan   Blue          None    4.5  31570.0
# 998   Honda  White          None    4.5   4001.0
# 999  Toyota   Blue          None    4.5  12732.0
#
# [1000 rows x 5 columns]

# %%
cs = pd.read_csv("car-sales-extended-missing-data.csv")

# %%
cs
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
cs.dropna()
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 994     BMW   Blue       163322.0    3.0  31666.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [773 rows x 5 columns]

# %%
# create new column from Series
seats = pd.Series([5,4,6,4,5])

# %%
car_table["Seats"] = seats

# %%
car_table["Seats"] = car_table["Seats"].fillna(5)

# %%
car_table
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   400000    5.0
# 1   Honda    Red          87899      4   500000    4.0
# 2  Toyota   Blue          32549      3   700000    6.0
# 3     Bmw  Black          11179      5  2200000    4.0
# 4  Nissan  White         213095      4   350000    5.0
# 5  Toyota  Green          99213      4   450000    5.0
# 6   Honda   Blue          45698      4   750000    5.0
# 7   Honda   Blue          54738      4   700000    5.0
# 8  Toyota  White          60000      4   625000    5.0
# 9  Nissan  White          31600      4   970000    5.0

# %%
car_table.loc[car_table["Seats"] == 5]
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats
# 0  Toyota  White         150043      4  400000    5.0
# 4  Nissan  White         213095      4  350000    5.0
# 5  Toyota  Green          99213      4  450000    5.0
# 6   Honda   Blue          45698      4  750000    5.0
# 7   Honda   Blue          54738      4  700000    5.0
# 8  Toyota  White          60000      4  625000    5.0
# 9  Nissan  White          31600      4  970000    5.0

# %%
# create new column from Python list //HERE length of list should match the number of rows//
fuel = [5.5, 6.5, 7.5,8.5,9.5,10,4,5,6,7]
car_table["Fuel per 100KM"] = fuel

# %%
car_table
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  Toyota  White         150043      4   400000    5.0             5.5
# 1   Honda    Red          87899      4   500000    4.0             6.5
# 2  Toyota   Blue          32549      3   700000    6.0             7.5
# 3     Bmw  Black          11179      5  2200000    4.0             8.5
# 4  Nissan  White         213095      4   350000    5.0             9.5
# 5  Toyota  Green          99213      4   450000    5.0            10.0
# 6   Honda   Blue          45698      4   750000    5.0             4.0
# 7   Honda   Blue          54738      4   700000    5.0             5.0
# 8  Toyota  White          60000      4   625000    5.0             6.0
# 9  Nissan  White          31600      4   970000    5.0             7.0

# %%
car_table["Total Fuel Used"] = car_table["Odometer (KM)"]/100 * car_table["Fuel per 100KM"]

# %%
car_table
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   400000    5.0             5.5
# 1   Honda    Red          87899      4   500000    4.0             6.5
# 2  Toyota   Blue          32549      3   700000    6.0             7.5
# 3     Bmw  Black          11179      5  2200000    4.0             8.5
# 4  Nissan  White         213095      4   350000    5.0             9.5
# 5  Toyota  Green          99213      4   450000    5.0            10.0
# 6   Honda   Blue          45698      4   750000    5.0             4.0
# 7   Honda   Blue          54738      4   700000    5.0             5.0
# 8  Toyota  White          60000      4   625000    5.0             6.0
# 9  Nissan  White          31600      4   970000    5.0             7.0
#
#    Total Fuel Used
# 0         8252.365
# 1         5713.435
# 2         2441.175
# 3          950.215
# 4        20244.025
# 5         9921.300
# 6         1827.920
# 7         2736.900
# ...

# %%
# create new column with a single value
car_table["Wheels"] = 4
car_table
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   400000    5.0             5.5
# 1   Honda    Red          87899      4   500000    4.0             6.5
# 2  Toyota   Blue          32549      3   700000    6.0             7.5
# 3     Bmw  Black          11179      5  2200000    4.0             8.5
# 4  Nissan  White         213095      4   350000    5.0             9.5
# 5  Toyota  Green          99213      4   450000    5.0            10.0
# 6   Honda   Blue          45698      4   750000    5.0             4.0
# 7   Honda   Blue          54738      4   700000    5.0             5.0
# 8  Toyota  White          60000      4   625000    5.0             6.0
# 9  Nissan  White          31600      4   970000    5.0             7.0
#
#    Total Fuel Used  Wheels
# 0         8252.365       4
# 1         5713.435       4
# 2         2441.175       4
# 3          950.215       4
# 4        20244.025       4
# ...

# %%
car_table["Passed Road Safety"] = True
car_table
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   400000    5.0             5.5
# 1   Honda    Red          87899      4   500000    4.0             6.5
# 2  Toyota   Blue          32549      3   700000    6.0             7.5
# 3     Bmw  Black          11179      5  2200000    4.0             8.5
# 4  Nissan  White         213095      4   350000    5.0             9.5
# 5  Toyota  Green          99213      4   450000    5.0            10.0
# 6   Honda   Blue          45698      4   750000    5.0             4.0
# 7   Honda   Blue          54738      4   700000    5.0             5.0
# 8  Toyota  White          60000      4   625000    5.0             6.0
# 9  Nissan  White          31600      4   970000    5.0             7.0
#
#    Total Fuel Used  Wheels  Passed Rpad Safety  Passed Rpad Safety L  \
# 0         8252.365       4                True                  True
# ...

# %%
car_table.dtypes
# Out:
# Make                   object
# Colour                 object
# Odometer (KM)           int64
# Doors                   int64
# Price                   int32
# Seats                 float64
# Fuel per 100KM        float64
# Total Fuel Used       float64
# Wheels                  int64
# Passed Rpad Safety       bool
# dtype: object

# %%
car_table = car_table.drop("Passed R0ad Safety", axis=1)

# %%
car_table
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White      93776.875      4   400000    5.0             5.5
# 1   Honda    Red      54936.875      4   500000    4.0             6.5
# 2  Toyota   Blue      20343.125      3   700000    6.0             7.5
# 3     Bmw  Black       6986.875      5  2200000    4.0             8.5
# 4  Nissan  White     133184.375      4   350000    5.0             9.5
# 5  Toyota  Green      62008.125      4   450000    5.0            10.0
# 6   Honda   Blue      28561.250      4   750000    5.0             4.0
# 7   Honda   Blue      34211.250      4   700000    5.0             5.0
# 8  Toyota  White      37500.000      4   625000    5.0             6.0
# 9  Nissan  White      19750.000      4   970000    5.0             7.0
#
#    Total Fuel Used  Wheels  Passed Road Safety
# 0         8252.365       4                True
# 1         5713.435       4                True
# ...

# %%
# to take a sample of data // index will shuffle
car_table.sample(frac=.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100KM  \
# 4  Nissan  White         213095      4  350000    5.0             9.5
# 9  Nissan  White          31600      4  970000    5.0             7.0
#
#    Total Fuel Used  Wheels  Passed Road Safety
# 4        20244.025       4                True
# 9         2212.000       4                True

# %%
car_table
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White      93776.875      4   400000    5.0             5.5
# 1   Honda    Red      54936.875      4   500000    4.0             6.5
# 2  Toyota   Blue      20343.125      3   700000    6.0             7.5
# 3     Bmw  Black       6986.875      5  2200000    4.0             8.5
# 4  Nissan  White     133184.375      4   350000    5.0             9.5
# 5  Toyota  Green      62008.125      4   450000    5.0            10.0
# 6   Honda   Blue      28561.250      4   750000    5.0             4.0
# 7   Honda   Blue      34211.250      4   700000    5.0             5.0
# 8  Toyota  White      37500.000      4   625000    5.0             6.0
# 9  Nissan  White      19750.000      4   970000    5.0             7.0
#
#    Total Fuel Used  Wheels  Passed Road Safety
# 0         8252.365       4                True
# 1         5713.435       4                True
# ...

# %%
# Apply function to a column
car_table["Price"] = car_table["Price"].apply(lambda x:x/100)
car_table
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White      93776.875      4   4000.0    5.0             5.5
# 1   Honda    Red      54936.875      4   5000.0    4.0             6.5
# 2  Toyota   Blue      20343.125      3   7000.0    6.0             7.5
# 3     Bmw  Black       6986.875      5  22000.0    4.0             8.5
# 4  Nissan  White     133184.375      4   3500.0    5.0             9.5
# 5  Toyota  Green      62008.125      4   4500.0    5.0            10.0
# 6   Honda   Blue      28561.250      4   7500.0    5.0             4.0
# 7   Honda   Blue      34211.250      4   7000.0    5.0             5.0
# 8  Toyota  White      37500.000      4   6250.0    5.0             6.0
# 9  Nissan  White      19750.000      4   9700.0    5.0             7.0
#
#    Total Fuel Used  Wheels  Passed Road Safety
# 0         8252.365       4                True
# 1         5713.435       4                True
# ...
